# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.0 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3JBFuln4h9XNiXtGTuEB")
project = rf.workspace("coba-lg8te").project("elc-ww0gu")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 81.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 100.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to elc-3 in yolov8:: 100%|██████████| 3990/3990 [00:00<00:00, 7157.37it/s]
# ...

# %%
# --- KONFIGURASI ---
# Tentukan lokasi folder output di Google Drive Anda
PROJECT_DIR = '/content/drive/MyDrive/Kuliah/Sem 5/P.Comvis/Tugas Akhir/YOLO/Elc_Class/YOLOv8_Training_ResultsV6'
EXPERIMENT_NAME = 'Epoch_200'
DATA_YAML_PATH = '/content/elc-3/data.yaml'

# Perintah Training
# PENTING: Menggunakan tanda kutip tunggal (') di sekitar {PROJECT_DIR}
# Ini mencegah spasi dalam path diinterpretasikan sebagai pemisah argumen oleh shell.
# !yolo task=detect mode=train model=yolov8n.pt data={DATA_YAML_PATH} epochs=200 imgsz=640 \
    project='{PROJECT_DIR}' name={EXPERIMENT_NAME}

# Tentukan path lengkap hasil training untuk digunakan di sel berikutnya
RESULTS_PATH = f'{PROJECT_DIR}/{EXPERIMENT_NAME}/'
print(f"✅ Training selesai. Hasil disimpan di: {RESULTS_PATH}")
# Out:
# ...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
